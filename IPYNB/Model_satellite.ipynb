# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd 'drive/My Drive/Satellite data'
# Out:
# /content/drive/My Drive/Satellite data

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 921kB 24.7MB/s
# ...
#      |████████████████████████████████| 11.8MB 19.5MB/s
# ...
#      |████████████████████████████████| 10.1MB 51.6MB/s
# ...

# %%
import geopandas as gpd
df1 = gpd.read_file('train-mixco_1_and_ebenezer.geojson')

# %%
np.random.seed(2)

# %%
data = ImageDataBunch.from_df('', df1, folder='Processed data_mixco_1_and_ebenezer_train', ds_tfms=get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.), 
                              size=128, bs=32,label_col=1, suffix='.tif').normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(12,9))

# %%
print(data.classes)
# Out:
# ['concrete_cement', 'healthy_metal', 'irregular_metal', 'other']

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 303MB/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
# ...

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.463652</td>
#       <td>1.123952</td>
#       <td>0.292537</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.068343</td>
#       <td>0.692208</td>
#       <td>0.213433</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.791076</td>
#       <td>0.664815</td>
#       <td>0.213433</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.655522</td>
#       <td>0.562200</td>
#       <td>0.183582</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.569977</td>
#       <td>0.538511</td>
#       <td>0.183582</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
learn.save('stage-1-50')

# %%
learn.load('stage-1-50')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2681 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# concrete_cement,concrete_cement,concrete_cement,concrete_cement,concrete_cement
# Path: .;
#
# Valid: LabelList (670 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# irregular_metal,irregular_metal,irregular_metal,irregular_metal,concrete_cement
# Path: .;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
# ...

# %%
img = learn.data.train_ds[0][0]
print(np.array(learn.predict(img)[2]))
# Out:
# [0.407572 0.586509 0.004723 0.001196]
